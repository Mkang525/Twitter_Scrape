# %%
# clone the following repo to install requirements:

# git clone --depth=1 https://github.com/twintproject/twint.git
# cd twint
# pip3 install . -r requirements.txt

# !pip install nest_asyncio

# %%
import twint
import nest_asyncio
nest_asyncio.apply()

# %%
# Configure
c = twint.Config()
c.Search = "bullying"
c.Store_json = True
c.Output = 'bully.json'

# Run
twint.run.Search(c)
# Out:
# 1356479508677812225 2021-02-01 21:48:11 -0800 <titchelak_> eu lembro que o pessoal do meu colégio fazia bullying cmg até pela franja torta que a minha mãe cortava, ficava todo mundo elogiando na minha frente perguntando quem tinha cortado pq queria cortar igual e na hora que eu virava as costas todo mundo ria
# 1356479436049117185 2021-02-01 21:47:54 -0800 <moth34553337> My friends are bullying me for being a techno Stan   @Technothepig 💔  https://t.co/YDa5Em8rlb
# 1356479415937617920 2021-02-01 21:47:49 -0800 <Colbs_Golbach_x> I guess were bullying me now oh well🤷‍♀️
# 1356479415245545473 2021-02-01 21:47:49 -0800 <louscardigan> @Iwtsire @soIorogue NOT YOU JOINING TUE BULLYING EW
# 1356479375550656512 2021-02-01 21:47:39 -0800 <dxlatto> já sofri bullying por ser loira rica filha do velho da lancha
# ...

# %%
import pandas as pd

# %%
data = pd.read_json('bully.json', lines=True)

# %%
data.shape

# %%
data.head()

# %%
# Can also type below into terminal and get same results
# twint -s "school violence" --json -o schviolence.json

data_2 = pd.read_json('school_violence.json', lines=True)

# %%
data_2.shape

# %%
data_2.head()
